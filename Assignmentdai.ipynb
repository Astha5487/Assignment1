# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("NY_Math_Test_Results_2006-2012.csv")

# %%
df
# Out:
#        Report Category Geographic Subdivision       Grade  Year  \
# 0             Citywide               Citywide           3  2006
# 1             Citywide               Citywide           3  2007
# 2             Citywide               Citywide           3  2008
# 3             Citywide               Citywide           3  2009
# 4             Citywide               Citywide           3  2010
# ...                ...                    ...         ...   ...
# 369537  Charter School                 84X730  All Grades  2008
# 369538  Charter School                 84X730  All Grades  2009
# 369539  Charter School                 84X730  All Grades  2010
# 369540  Charter School                 84X730  All Grades  2011
# 369541  Charter School                 84X730  All Grades  2012
#
#        Student Category  Number Tested Mean Scale Score Num Level 1  \
# 0          All Students          73413              674        6714
# ...

# %% [markdown]
# * Analyzing the dataset reveals performance trends across different geographic regions, grades, and student categories, highlighting disparities and progress over time. By examining proficiency levels (Levels 1-4), insights into areas needing improvement and high-performing groups are gained. This helps guide targeted interventions and track the overall effectiveness of educational strategies.

# %%
df.head()
# Out:
#   Report Category Geographic Subdivision Grade  Year Student Category  \
# 0        Citywide               Citywide     3  2006     All Students
# 1        Citywide               Citywide     3  2007     All Students
# 2        Citywide               Citywide     3  2008     All Students
# 3        Citywide               Citywide     3  2009     All Students
# 4        Citywide               Citywide     3  2010     All Students
#
#    Number Tested Mean Scale Score Num Level 1 Pct Level 1 Num Level 2  \
# 0          73413              674        6714         9.1       11431
# 1          72196              683        3907         5.4        8918
# 2          70062              685        2143         3.1        6854
# 3          71376              689         922         1.3        5196
# 4          71351              690        8555          12       24086
#
#   Pct Level 2 Num Level 3 Pct Level 3 Num Level 4 Pct Level 4  \
# ...

# %% [markdown]
# * Running df.head() on this dataset gives a preview of the first few rows, allowing you to quickly understand the structure, data types, and spot-check for any anomalies or missing values. It provides an initial sense of how different regions, grades, and student categories are performing across proficiency levels.

# %%
df.tail()
# Out:
#        Report Category Geographic Subdivision       Grade  Year  \
# 369537  Charter School                 84X730  All Grades  2008
# 369538  Charter School                 84X730  All Grades  2009
# 369539  Charter School                 84X730  All Grades  2010
# 369540  Charter School                 84X730  All Grades  2011
# 369541  Charter School                 84X730  All Grades  2012
#
#        Student Category  Number Tested Mean Scale Score Num Level 1  \
# 369537     All Students            163              NaN           6
# 369538     All Students            161              NaN           3
# 369539     All Students            161              NaN           3
# 369540     All Students            157              681           2
# 369541     All Students            147              685           5
#
#        Pct Level 1 Num Level 2 Pct Level 2 Num Level 3 Pct Level 3  \
# 369537         3.7          35        21.5         104        63.8
# ...

# %% [markdown]
# * Running df.tail() provides insights into the last few rows of the dataset, helping identify any unusual entries, such as outliers, missing data, or inconsistencies at the end of the dataset. It also allows you to check the completeness of the dataset and ensure there are no unexpected patterns or errors in the final records

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369542 entries, 0 to 369541
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Report Category         369542 non-null  object
#  1   Geographic Subdivision  369542 non-null  object
#  2   Grade                   369542 non-null  object
#  3   Year                    369542 non-null  int64
#  4   Student Category        369542 non-null  object
#  5   Number Tested           369542 non-null  int64
#  6   Mean Scale Score        322592 non-null  object
#  7   Num Level 1             369542 non-null  object
#  8   Pct Level 1             369542 non-null  object
#  9   Num Level 2             369542 non-null  object
#  10  Pct Level 2             369542 non-null  object
#  11  Num Level 3             369542 non-null  object
#  12  Pct Level 3             369542 non-null  object
#  13  Num Level 4             369542 non-null  object
# ...

# %% [markdown]
# * Running df.info() gives an overview of the dataset's structure, including the number of entries, column names, data types, and non-null counts. This helps identify missing values, assess the data types (e.g., numerical, categorical), and understand the memory usage. It's useful for determining if any data cleaning or type conversions are needed before further analysis.
#
# * The dataset has 369,542 entries with some missing values in key columns like Mean Scale Score. Most columns are object types, which may need conversion for numeric analysis. Memory usage is 47.9 MB, and optimizing data types could improve efficiency.

# %%
df.describe()
# Out:
#                 Year  Number Tested
# count  369542.000000  369542.000000
# mean     2009.066734     321.255630
# std         1.991440    4125.189515
# min      2006.000000       1.000000
# 25%      2007.000000      15.000000
# 50%      2009.000000      48.000000
# 75%      2011.000000     111.000000
# max      2012.000000  446197.000000

# %% [markdown]
# *
# The df.describe() output for the columns Year and Number Tested provides the following insights:
#
# Year: The data spans from 2006 to 2012, with a mean year of around 2009. This suggests the dataset covers a 6-year period.
#
# Number Tested: The number of students tested varies significantly, ranging from 1 to 446,197, with a median of 48. The high standard deviation indicates large variability in the number of students tested across different entries, possibly reflecting different school sizes or regions

# %%
numeric_columns = ['Mean Scale Score', 'Num Level 1', 'Pct Level 1', 'Num Level 2', 
                   'Pct Level 2', 'Num Level 3', 'Pct Level 3', 'Num Level 4', 
                   'Pct Level 4', 'Num Level 3 and 4', 'Pct Level 3 and 4']

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Check for missing values in important columns
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)

# Drop rows with missing 'Mean Scale Score' (if necessary)
df_clean = df.dropna(subset=['Mean Scale Score'])
# Out:
# Missing values in each column:
#  Report Category               0
# Geographic Subdivision        0
# Grade                         0
# Year                          0
# Student Category              0
# Number Tested                 0
# Mean Scale Score          91882
# Num Level 1               48837
# Pct Level 1               48837
# Num Level 2               48837
# Pct Level 2               48837
# Num Level 3               48837
# Pct Level 3               48837
# Num Level 4               48632
# Pct Level 4               48837
# Num Level 3 and 4         48634
# Pct Level 3 and 4         48839
# dtype: int64

# %% [markdown]
# * The missing values insight shows that:
#
# Key Gaps: Mean Scale Score has the most missing values (91,882), while other columns like proficiency levels (Num Level 1-4, Pct Level 1-4, and combined levels) are missing in around 48,000 entries.
#
# Implications: These gaps may affect the analysis of student performance, particularly in assessing proficiency and scale scores, and require handling (e.g., imputation or exclusion) to maintain data quality for analysis.
#
# Complete Data: Certain columns like Report Category, Geographic Subdivision, Grade, and Number Tested have no missing values, ensuring full coverage for these aspects.

# %%
def plot_categorical_distributions(column):
    plt.figure(figsize=(6, 4))
    sns.countplot(y=column, data=df_clean, order=df_clean[column].value_counts().index)
    plt.title(f"Frequency Distribution of {column}")
    plt.show()

# Frequency distribution for 'Grade'
plot_categorical_distributions('Grade')

# Frequency distribution for 'Report Category'
plot_categorical_distributions('Report Category')

# Frequency distribution for 'Student Category'
plot_categorical_distributions('Student Category')

# Frequency distribution for 'Year'
plot_categorical_distributions('Year')

# %% [markdown]
# ## First Graph Insight - Frequency distribution of Grade vs Count
#
# * The graph displays the frequency distribution of grades in the dataset. Here's the insight:
#
# Grades 3 through 8 are represented, with Grade 8 having the most entries, followed by Grade 7.
# The lower grades (3, 4, 5) have relatively fewer entries, while the middle grades (6 and 7) show higher frequency counts.
# The "All Grades" category also appears, representing a consolidated category across grades.
# This suggests that data is well-represented across the higher grades, particularly in Grades 6 through 8, while lower grades might have slightly less data coverage

# %% [markdown]
# ## Second Graph Insight - Frequency distribution of Report Category vs Count
# * The top chart represents different categories of reporting within an educational system.
# The largest portion is labeled "School," indicating that the majority of reports come from individual schools.
# Other categories like "District," "Borough," "Charter School," and "Citywide" show significantly lower counts.
# Insights:
# Most data or reports are being aggregated at the school level, while other administrative levels like districts or boroughs are contributing far fewer reports.

# %% [markdown]
# ## Third Graph Insight- Frequency distribution of Student Category vs count
# * This chart shows the distribution of students across different categories.
# Key insights:
# The "Male" category slightly exceeds the "Female" category in terms of count.
# The "All Students" category represents the total count.
# EP (likely meaning "English Proficient") and "Not SWD" (Students without Disabilities) have a large presence, indicating these groups form a significant portion of the student body.
# Ethnic and demographic categories like "Hispanic," "Black," "Asian," "White" are represented, with Hispanic and Black students forming larger groups compared to Asians and Whites.
# There is also a visible count of "ELL" (English Language Learners) students.
# "SWD" (Students with Disabilities) and "ELLs" (likely another variation of English Language Learners) are well represented, though smaller in size compared to general student categories.

# %% [markdown]
# ## Fourth Graph Insights - Frequency distribution of year vs count
# * The years 2012 and 2011 have the highest data counts.
# There is a consistent drop-off in data frequency as you go further back in time, with 2006 having the lowest count.
# Overall Insights:
# The student population is diverse, with particular emphasis on gender, language proficiency, ethnicity, and disability status. The majority of the data comes from recent years (2011-2012), with fewer entries from earlier years like 2006-2007.
# This could imply that either data collection improved over time, or more students were present in the system during these years

# %%
print("Summary statistics:\n", df_clean.describe())

# Function to plot histograms for numerical variables
def plot_numeric_histogram(column, bins=20):
    plt.figure(figsize=(4,2))
    sns.histplot(df_clean[column].dropna(), kde=True, bins=bins)
    plt.title(f"Distribution of {column}")
    plt.show()

# Plot histograms for important numerical columns
plot_numeric_histogram('Mean Scale Score')
plot_numeric_histogram('Pct Level 1')
plot_numeric_histogram('Pct Level 2')
plot_numeric_histogram('Pct Level 3')
plot_numeric_histogram('Pct Level 4')
# Out:
# Summary statistics:
#                  Year  Number Tested  Mean Scale Score    Num Level 1  \
# count  277660.000000  277660.000000     277660.000000  277660.000000
# mean     2009.215324     396.786826        672.371285      36.359245
# std         2.026243    4755.435067         24.683585     467.367386
# min      2006.000000       6.000000        516.000000       0.000000
# 25%      2007.000000      25.000000        658.000000       1.000000
# 50%      2009.000000      55.000000        674.000000       3.000000
# 75%      2011.000000     111.000000        689.000000      10.000000
# max      2012.000000  446197.000000        772.000000   70090.000000
#
#          Pct Level 1    Num Level 2    Pct Level 2    Num Level 3  \
# count  277660.000000  277660.000000  277660.000000  277660.000000
# mean       10.844134     105.092347      27.561152     170.630364
# std        14.142800    1295.467572      17.812807    2122.069132
# ...

# %% [markdown]
# ## First Graph insight- Distribution of Mean Scale score vs Mean scale score
# *The graph shows the distribution of the mean scale score in the dataset. The histogram is bell-shaped, indicating a normal distribution. The peak of the distribution is around 650, suggesting that this is the most common range of mean scale scores. The distribution is relatively symmetric, with a slight skew to the right. This means that there are a few higher scores that are pulling the average to the right. Overall, the distribution suggests that the majority of students scored around 650 on the scale, with a smaller number of students scoring higher or lower.

# %% [markdown]
# ## Second Graph Insight - Distribution of Pct Level 1 vs Pct Level 1
# * The histogram for Pct Level 1 shows a right-skewed distribution, indicating a tail to the right. This means that there are a few students who achieved very high percentages at this level. The peak of the distribution is around 50, suggesting that a larger number of students achieved a percentage of around 50 in Pct Level 1. Overall, the distribution suggests that most students achieved moderate percentages at this level, with a smaller number of students achieving very high or very low percentages.

# %% [markdown]
# ## Third Graph Insight- Distribution of Pct level 2 vs Pct level 2
# * The histogram for Pct Level 2 shows a right-skewed distribution, indicating a tail to the right. This means that there are a few students who achieved very high percentages at this level. The peak of the distribution is around 30, suggesting that a larger number of students achieved a percentage of around 30 in Pct Level 2. Overall, the distribution suggests that most students achieved moderate percentages at this level, with a smaller number of students achieving very high or very low percentages

# %% [markdown]
# ## Fourth Graph Insight- Distribution of Pct level 3 vs Pct level 3
# * The histogram for Pct Level 3 shows a right-skewed distribution, indicating a tail to the right. This means that there are a few students who achieved very high percentages at this level. The peak of the distribution is around 40, suggesting that a larger number of students achieved a percentage of around 40 in Pct Level 3. Overall, the distribution suggests that most students achieved moderate percentages at this level, with a smaller number of students achieving very high or very low percentages.

# %% [markdown]
# ## Fifth Graph Insight- Distribution of Pct level 4 vs Pct level 4
# * The histogram for Pct Level 4 shows a right-skewed distribution, indicating a tail to the right. This means that there are a few students who achieved very high percentages at this level. The peak of the distribution is around 20, suggesting that a larger number of students achieved a percentage of around 20 in Pct Level 4. Overall, the distribution suggests that most students achieved moderate percentages at this level, with a smaller number of students achieving very high or very low percentages.

# %% [markdown]
# ### Function to create a boxplot for a numerical variable
# def plot_boxplot(column):
#     plt.figure(figsize=(6, 4))
#     sns.boxplot(x=column, data=df_clean)
#     plt.title(f"Boxplot of {column}")
#     plt.show()
#
# # Create boxplots for numerical variables
# plot_boxplot('Mean Scale Score')
# plot_boxplot('Pct Level 1')
# plot_boxplot('Pct Level 2')
# plot_boxplot('Pct Level 3')
# plot_boxplot('Pct Level 4')

# %%
# Frequency distribution of 'Grade'
print(df_clean['Grade'].value_counts())

# Frequency distribution of 'Year'
print(df_clean['Year'].value_counts())
# Out:
# Grade
# 3             49021
# 4             48579
# 5             48451
# 6             35090
# All Grades    34931
# 7             31568
# 8             30020
# Name: count, dtype: int64
# Year
# 2012    47504
# 2011    47293
# 2009    37421
# 2010    37413
# 2008    36640
# 2007    36083
# 2006    35306
# Name: count, dtype: int64

# %% [markdown]
# *
# The frequency distribution for grades shows that Grades 3, 4, and 5 have the highest counts, each around 49,000 entries, while Grades 6, 7, and 8 show decreasing frequencies, with Grade 8 having the least at 30,020. The "All Grades" category has 34,931 entries, providing a summary across grades. For the year distribution, 2011 and 2012 have the most data (approximately 47,000 entries), indicating strong coverage in recent years, while earlier years (2006-2009) have fewer entries, with 35,306 for 2006. This suggests robust data for analysis of lower grades and more recent trends, but potential gaps in higher grade and earlier year data could affect the overall insights.

# %%
# Visualize missing values using a heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Heatmap of Missing Values')
plt.show()

# %% [markdown]
# * The provided heatmap illustrates the distribution of missing values across various features in a dataset. Darker colors indicate a higher proportion of missing data. Key observations include a substantial number of missing values in columns such as "Grade", "Year", and "Student Category". This suggests the need for careful consideration and appropriate handling of missing data to maintain data integrity and ensure accurate analysis

# %%
# Compute the correlation matrix for numerical columns
numeric_cols = ['Number Tested', 'Mean Scale Score', 'Pct Level 1', 'Pct Level 2', 
                'Pct Level 3', 'Pct Level 4', 'Pct Level 3 and 4']

correlation_matrix = df[numeric_cols].corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# * The correlation matrix shows that higher mean scale scores are strongly associated with higher percentages of students in Levels 3 and 4 (positive correlations with +0.79 and +0.82), while negatively correlated with lower-performing students in Levels 1 and 2 (-0.76 and -0.57). Pct Level 1 and Pct Level 2 also have strong negative correlations with Pct Level 3 and 4, indicating that schools with more students in lower levels tend to have fewer high performers. This highlights a clear performance divide between higher and lower levels
